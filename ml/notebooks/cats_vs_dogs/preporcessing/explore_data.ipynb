# %% [markdown]
# Load and explore the data

# %% [markdown]
# Import libraries

# %%
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# Load the data

# %%
#load data and metadata of cats_vs_dogs from tensorflow datasets 
data, metadata = tfds.load('cats_vs_dogs', as_supervised=True, with_info=True)
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# ...
# Generating train examples...:   0%|          | 0/23262 [00:00<?, ? examples/s]
# WARNING:absl:1738 images were corrupted and were skipped
# Shuffling /Users/josecamacho/tensorflow_datasets/cats_vs_dogs/4.0.0.incompleteMLFCQG/cats_vs_dogs-train.tfreco…
# Dataset cats_vs_dogs downloaded and prepared to /Users/josecamacho/tensorflow_datasets/cats_vs_dogs/4.0.0. Subsequent calls will reuse this data.

# %% [markdown]
# Show images from the dataset

# %%
#Show 5 images of simple form
tfds.as_dataframe(data['train'].take(5), metadata)
# Out:
# 2023-05-19 22:57:30.388950: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [8]
# 	 [[{{node Placeholder/_3}}]]
# 2023-05-19 22:57:30.390065: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [8]
# 	 [[{{node Placeholder/_0}}]]
#                                                image  label
# 0  [[[242, 248, 248], [240, 246, 246], [235, 239,...      1
# 1  [[[215, 165, 114], [187, 135, 85], [232, 176, ...      1
# 2  [[[177, 183, 157], [185, 191, 165], [192, 198,...      1
# 3  [[[92, 66, 7], [93, 67, 8], [93, 67, 8], [93, ...      0
# ...

# %%
#Show resize and tranformed images
IMG_SIZE = 100

plt.figure(figsize=(20,20))
for i, (image, label) in enumerate(data['train'].take(20)):
    image = cv2.resize(image.numpy(), (IMG_SIZE, IMG_SIZE))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    plt.subplot(4, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(image, cmap='gray')
# Out:
# 2023-05-19 22:57:41.096563: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int64 and shape [8]
# 	 [[{{node Placeholder/_4}}]]
# 2023-05-19 22:57:41.097184: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype string and shape [8]
# 	 [[{{node Placeholder/_2}}]]
